# %%
# !pip install tensorflow

# %%
import tensorflow as tf

a = tf.constant(3)
b = tf.constant(7)

added = tf.math.add(a, b)

print("a: ", a.numpy())
print("b: ", b.numpy())
print("Addition of a and b: ", added.numpy())
print(a)  # Tensor object
# Out:
# a:  3
# b:  7
# Addition of a and b:  10
# tf.Tensor(3, shape=(), dtype=int32)
